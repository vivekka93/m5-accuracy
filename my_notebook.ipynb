# %%
import pandas as pd
import numpy as np
import gc
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import TimeSeriesSplit
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_columns', None)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ["int16", "int32", "int64", "float16", "float32", "float64"]
    start_mem = df.memory_usage().sum() / 1024 ** 2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:    numerics = ["int16", "int32", "int64", "float16", "float32", "float64"]
    start_mem = df.memory_usage().sum() / 1024 ** 2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if (
                    c_min > np.finfo(np.float16).min
                    and c_max < np.finfo(np.float16).max
                ):
                    df[col] = df[col].astype(np.float16)
                elif (
                    c_min > np.finfo(np.float32).min
                    and c_max < np.finfo(np.float32).max
                ):
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024 ** 2
    if verbose:
        print(
            "Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)".format(
                end_mem, 100 * (start_mem - end_mem) / start_mem
            )
        )
    return df

# %%
def read_data():
    print("Reading files...")

    calendar = pd.read_csv("calendar.csv").pipe(reduce_mem_usage)
    sell_prices = pd.read_csv("sell_prices.csv").pipe(reduce_mem_usage)
    sales_train_val = pd.read_csv("sales_train_validation.csv").pipe(
        reduce_mem_usage
    )
    submission = pd.read_csv("sample_submission.csv").pipe(
        reduce_mem_usage
    )

    print("Calendar shape:", calendar.shape)
    print("Sell prices shape:", sell_prices.shape)
    print("Sales train shape:", sales_train_val.shape)
    print("Submission shape:", submission.shape)

    return calendar, sell_prices, sales_train_val, submission

# %%
calendar, sell_prices, sales_train_val, submission = read_data()
# Out:
# Reading files...
# Mem. usage decreased to  0.12 Mb (0.0% reduction)
# Mem. usage decreased to 130.48 Mb (23.1% reduction)
# Mem. usage decreased to 95.00 Mb (0.0% reduction)
# Mem. usage decreased to  2.09 Mb (0.0% reduction)
# Calendar shape: (1969, 14)
# Sell prices shape: (6841121, 4)
# Sales train shape: (30490, 1919)
# Submission shape: (60980, 29)

# %% [markdown]
# # Transforming sales data

# %%
def melt(
    sales_train_val, submission, nrows=55_000_000, verbose=True,
):
    # melt sales data, get it ready for training
    id_columns = ["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"]
    sales_train_val = pd.melt(
        sales_train_val, id_vars=id_columns, var_name="day", value_name="demand",
    )

    sales_train_val = reduce_mem_usage(sales_train_val)

    # separate test dataframes.
    test1 = submission[submission["id"].str.contains("validation")]
    # test2 = submission[submission["id"].str.contains("evaluation")]

    # change column names.
    test1.columns = ["id"] + [f"d_{x}".format(x) for x in range(1914, 1914 + 28)]
    # test2.columns = ["id"] + [f"d_{x}".format(x) for x in range(1942, 1942 + 28)]
    # get product table.
    product = sales_train_val[id_columns].drop_duplicates()

    # merge with product table
    # test2["id"] = test2["id"].str.replace("_evaluation", "_validation")
    test1 = test1.merge(product, how="left", on="id")
#     test2 = test2.merge(product, how="left", on="id")
#     test2["id"] = test2["id"].str.replace("_validation", "_evaluation")

    test1 = pd.melt(test1, id_vars=id_columns, var_name="day", value_name="demand")
    # test2 = pd.melt(test2, id_vars=id_columns, var_name="day", value_name="demand")

    sales_train_val["part"] = "train"
    test1["part"] = "test1"
    # test2["part"] = "test2"

    # data = pd.concat([sales_train_val, test1, test2], axis=0)

    data = pd.concat([sales_train_val, test1], axis=0)

    del sales_train_val, test1 # test2

    # get only a sample for fast training.
    data = data.loc[nrows:]

    # delete test2 for now.
    # data = data[data["part"] != "test2"]

    gc.collect()

    return data


def merge(data, calendar, sell_prices, verbose=True):
    # drop some calendar features.
    calendar = calendar.drop(["weekday", "wday", "month", "year"], axis=1)

    # notebook crashes with the entire dataset.
    data = pd.merge(data, calendar, how="left", left_on=["day"], right_on=["d"])
    data = data.drop(["d", "day"], axis=1)


    # get the sell price data (this feature should be very important).
    data = data.merge(sell_prices, on=["store_id", "item_id", "wm_yr_wk"], how="left")

    return data

# %%
data = melt(sales_train_val, submission, nrows=27_500_000)
data = merge(data, calendar, sell_prices)
# Out:
# Mem. usage decreased to 3226.27 Mb (0.0% reduction)

# %%
calendar.head(2)
# Out:
#          date  wm_yr_wk   weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101    Sunday     2      1  2011  d_2          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0

# %%
data.head(2)
# Out:
#                                 id          item_id      dept_id     cat_id  \
# 0  HOUSEHOLD_1_514_WI_3_validation  HOUSEHOLD_1_514  HOUSEHOLD_1  HOUSEHOLD
# 1  HOUSEHOLD_1_515_WI_3_validation  HOUSEHOLD_1_515  HOUSEHOLD_1  HOUSEHOLD
#
#   store_id state_id  demand   part        date  wm_yr_wk event_name_1  \
# 0     WI_3       WI      16  train  2013-07-18     11325          NaN
# 1     WI_3       WI       1  train  2013-07-18     11325          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
#
#    sell_price
# 0    3.500000
# 1    2.470703

# %%
def encode_categoricals(df):
    nan_features = ["event_name_1", "event_type_1", "event_name_2", "event_type_2"]
    for feature in nan_features:
        df[feature] = df[feature].fillna("MISSING")

    cat_cols = [
        "item_id",
        "dept_id",
        "cat_id",
        "store_id",
        "state_id",
        "event_name_1",
        "event_type_1",
        "event_name_2",
        "event_type_2",
    ]

    for col in cat_cols:
        encoder = LabelEncoder()
        df[col] = encoder.fit_transform(df[col])

    return df

def add_agg_features(df):
    # rolling demand features.
    for shift in [28, 29, 30]:
        df[f"shift_t{shift}"] = df.groupby(["id"])["demand"].transform(
            lambda x: x.shift(shift)
        )

    for size in [7, 30]:
        df[f"rolling_std_t{size}"] = df.groupby(["id"])["demand"].transform(
            lambda x: x.shift(28).rolling(size).std()
        )

    for size in [7, 30, 90, 180]:
        df[f"rolling_mean_t{size}"] = df.groupby(["id"])["demand"].transform(
            lambda x: x.shift(28).rolling(size).mean()
        )

    df["rolling_skew_t30"] = df.groupby(["id"])["demand"].transform(
        lambda x: x.shift(28).rolling(30).skew()
    )
    df["rolling_kurt_t30"] = df.groupby(["id"])["demand"].transform(
        lambda x: x.shift(28).rolling(30).kurt()
    )
    # price features
    df["shift_price_t1"] = df.groupby(["id"])["sell_price"].transform(
        lambda x: x.shift(1)
    )
    df["price_change_t1"] = (df["shift_price_t1"] - df["sell_price"]) / (
        df["shift_price_t1"]
    )
    df["rolling_price_max_t365"] = df.groupby(["id"])["sell_price"].transform(
        lambda x: x.shift(1).rolling(365).max()
    )
    df["price_change_t365"] = (df["rolling_price_max_t365"] - df["sell_price"]) / (
        df["rolling_price_max_t365"]
    )

    df["rolling_price_std_t7"] = df.groupby(["id"])["sell_price"].transform(
        lambda x: x.rolling(7).std()
    )
    df["rolling_price_std_t30"] = df.groupby(["id"])["sell_price"].transform(
        lambda x: x.rolling(30).std()
    )
    return df.drop(["rolling_price_max_t365", "shift_price_t1"], axis=1)

# %%
def add_time_features(df):
    df["date"] = pd.to_datetime(df["date"])
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["week"] = df["date"].dt.week
    df["day"] = df["date"].dt.day
    df["dayofweek"] = df["date"].dt.dayofweek
    df["is_weekend"] = df["dayofweek"].isin([5, 6])
    return df

# %%
data = encode_categoricals(data)
data = add_agg_features(data)
data = add_time_features(data)
data = reduce_mem_usage(data)
# Out:
# Mem. usage decreased to 2658.78 Mb (42.9% reduction)

# %%
data.head(2)
# Out:
#                                 id  item_id  dept_id  cat_id  store_id  \
# 0  HOUSEHOLD_1_514_WI_3_validation     2506        5       2         9
# 1  HOUSEHOLD_1_515_WI_3_validation     2507        5       2         9
#
#    state_id  demand   part       date  wm_yr_wk  event_name_1  event_type_1  \
# 0         2      16  train 2013-07-18     11325            13             1
# 1         2       1  train 2013-07-18     11325            13             1
#
#    event_name_2  event_type_2  snap_CA  snap_TX  snap_WI  sell_price  \
# 0             1             1        0        0        0    3.500000
# 1             1             1        0        0        0    2.470703
#
#    shift_t28  shift_t29  shift_t30  rolling_std_t7  rolling_std_t30  \
# 0        NaN        NaN        NaN             NaN              NaN
# 1        NaN        NaN        NaN             NaN              NaN
#
#    rolling_mean_t7  rolling_mean_t30  rolling_mean_t90  rolling_mean_t180  \
# 0              NaN               NaN               NaN                NaN
# 1              NaN               NaN               NaN                NaN
#
#    rolling_skew_t30  rolling_kurt_t30  price_change_t1  price_change_t365  \
# 0               NaN               NaN              NaN                NaN
# 1               NaN               NaN              NaN                NaN
#
#    rolling_price_std_t7  rolling_price_std_t30  year  month  week  day  \
# 0                   NaN                    NaN  2013      7    29   18
# 1                   NaN                    NaN  2013      7    29   18
#
#    dayofweek  is_weekend
# 0          3       False
# 1          3       False

# %%
def train_lgb(bst_params, fit_params, X, y, cv):
    models = []

    for idx_fold, (idx_trn, idx_val) in enumerate(cv.split(X, y)):
        print(f"\n---------- Fold: ({idx_fold + 1} / {cv.get_n_splits()}) ----------\n")

        X_trn, X_val = X.iloc[idx_trn], X.iloc[idx_val]
        y_trn, y_val = y.iloc[idx_trn], y.iloc[idx_val]
        train_set = lgb.Dataset(X_trn, label=y_trn)
        val_set = lgb.Dataset(X_val, label=y_val)

        model = lgb.train(
            bst_params,
            train_set,
            valid_sets=[train_set, val_set],
            valid_names=["train", "valid"],
            **fit_params,
        )
        models.append(model)

    return models

# %%
features = [
    "item_id",
    "dept_id",
    "cat_id",
    "store_id",
    "state_id",
    "event_name_1",
    "event_type_1",
    "event_name_2",
    "event_type_2",
    "snap_CA",
    "snap_TX",
    "snap_WI",
    "sell_price",
    # aggregation features.
    "shift_t28",
    "shift_t29",
    "shift_t30",
    "rolling_mean_t7",
    "rolling_std_t7",
    "rolling_mean_t30",
    "rolling_mean_t90",
    "rolling_mean_t180",
    "rolling_std_t30",
    "price_change_t1",
    "price_change_t365",
    "rolling_price_std_t7",
    "rolling_price_std_t30",
    "rolling_skew_t30",
    "rolling_kurt_t30",
    # time features.
    "year",
    "month",
    "week",
    "day",
    "dayofweek",
]
# prepare training and test data.
# 2011-01-29 ~ 2016-04-24 : d_1    ~ d_1913
# 2016-04-25 ~ 2016-05-22 : d_1914 ~ d_1941 (public)
# 2016-05-23 ~ 2016-06-19 : d_1942 ~ d_1969 (private)

mask1 = data["date"] <= "2016-03-27"  # noqa
mask2 = data["date"] <= "2016-04-24"  # noqa
X_train = data[mask2][features]
y_train = data[mask2]["demand"]

# X_val = data[~mask1 & mask2][features]
# y_val = data[~mask1 & mask2]["demand"]

X_test = data[~mask2][features]
id_date = data[~mask2][["id", "date"]]  # keep these two columns to use later.

del data
gc.collect()
# Out:
# 70

# %%
bst_params = {
    "boosting_type": "gbdt",
    "metric": "rmse",
    "objective": "regression",
    "n_jobs": -1,
    "seed": 42,
    "learning_rate": 0.1,
    "bagging_fraction": 0.75,
    "bagging_freq": 10,
    "colsample_bytree": 0.75,
}

fit_params = {
    "num_boost_round": 100_000,
    "early_stopping_rounds": 50,
    "verbose_eval": 100,
}

cv = TimeSeriesSplit(n_splits=5)
models = train_lgb(bst_params, fit_params, X_train, y_train, cv)
# Out:
# ---------- Fold: (1 / 5) ----------
#
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.73386	valid's rmse: 2.68226
# Early stopping, best iteration is:
# [71]	train's rmse: 2.78509	valid's rmse: 2.6803
#
# ---------- Fold: (2 / 5) ----------
#
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.58326	valid's rmse: 2.38065
# Early stopping, best iteration is:
# [72]	train's rmse: 2.63254	valid's rmse: 2.37629
#
# ---------- Fold: (3 / 5) ----------
#
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.48734	valid's rmse: 2.27369
# [200]	train's rmse: 2.41731	valid's rmse: 2.26185
# [300]	train's rmse: 2.36948	valid's rmse: 2.25155
# [400]	train's rmse: 2.33358	valid's rmse: 2.24846
# Early stopping, best iteration is:
# [437]	train's rmse: 2.32289	valid's rmse: 2.24614
#
# ---------- Fold: (4 / 5) ----------
#
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.4316	valid's rmse: 2.32449
# [200]	train's rmse: 2.36835	valid's rmse: 2.31036
# [300]	train's rmse: 2.33058	valid's rmse: 2.30468
# Early stopping, best iteration is:
# [320]	train's rmse: 2.32367	valid's rmse: 2.30353
#
# ---------- Fold: (5 / 5) ----------
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-cdd9c1c5fe08> in <module>()
#      18
#      19 cv = TimeSeriesSplit(n_splits=5)
# ---> 20 models = train_lgb(bst_params, fit_params, X_train, y_train, cv)
#
# <ipython-input-17-d2088a58a869> in train_lgb(bst_params, fit_params, X, y, cv)
#      15             valid_sets=[train_set, val_set],
#      16             valid_names=["train", "valid"],
# ---> 17             **fit_params,
#      18         )
#      19         models.append(model)
#
# D:\ProgramFiles\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     230             booster.set_train_data_name(train_data_name)
#     231         for valid_set, name_valid_set in zip_(reduced_valid_sets, name_valid_sets):
# --> 232             booster.add_valid(valid_set, name_valid_set)
#     233     finally:
#     234         train_set._reverse_update_params()
#
# D:\ProgramFiles\Anaconda3\lib\site-packages\lightgbm\basic.py in add_valid(self, data, name)
#    1893         _safe_call(_LIB.LGBM_BoosterAddValidData(
#    1894             self.handle,
# -> 1895             data.construct().handle))
#    1896         self.valid_sets.append(data)
#    1897         self.name_valid_sets.append(name)
#
# D:\ProgramFiles\Anaconda3\lib\site-packages\lightgbm\basic.py in construct(self)
#    1051                                     weight=self.weight, group=self.group,
#    1052                                     init_score=self.init_score, predictor=self._predictor,
# -> 1053                                     silent=self.silent, feature_name=self.feature_name, params=self.params)
#    1054                 else:
#    1055                     # construct subset
#
# D:\ProgramFiles\Anaconda3\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     885             self.__init_from_csc(data, params_str, ref_dataset)
#     886         elif isinstance(data, np.ndarray):
# --> 887             self.__init_from_np2d(data, params_str, ref_dataset)
#     888         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#     889             self.__init_from_list_np2d(data, params_str, ref_dataset)
#
# D:\ProgramFiles\Anaconda3\lib\site-packages\lightgbm\basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#     922         self.handle = ctypes.c_void_p()
#     923         if mat.dtype == np.float32 or mat.dtype == np.float64:
# --> 924             data = np.array(mat.reshape(mat.size), dtype=mat.dtype, copy=False)
#     925         else:  # change non-float data to float data, need to copy
#     926             data = np.array(mat.reshape(mat.size), dtype=np.float32)
#
# MemoryError:

# %%
X_train.head(10)
# Out:
#    item_id  dept_id  cat_id  store_id  state_id  event_name_1  event_type_1  \
# 0     2506        5       2         9         2            13             1
# 1     2507        5       2         9         2            13             1
# 2     2508        5       2         9         2            13             1
# 3     2509        5       2         9         2            13             1
# 4     2510        5       2         9         2            13             1
# 5     2511        5       2         9         2            13             1
# 6     2512        5       2         9         2            13             1
# 7     2513        5       2         9         2            13             1
# 8     2514        5       2         9         2            13             1
# 9     2515        5       2         9         2            13             1
#
#    event_name_2  event_type_2  snap_CA  snap_TX  snap_WI  sell_price  \
# 0             1             1        0        0        0    3.500000
# 1             1             1        0        0        0    2.470703
# 2             1             1        0        0        0    1.980469
# 3             1             1        0        0        0    0.979980
# 4             1             1        0        0        0         NaN
# 5             1             1        0        0        0    4.878906
# 6             1             1        0        0        0    5.480469
# 7             1             1        0        0        0    0.970215
# 8             1             1        0        0        0    1.839844
# 9             1             1        0        0        0         NaN
#
#    shift_t28  shift_t29  shift_t30  rolling_mean_t7  rolling_std_t7  \
# 0        NaN        NaN        NaN              NaN             NaN
# 1        NaN        NaN        NaN              NaN             NaN
# 2        NaN        NaN        NaN              NaN             NaN
# 3        NaN        NaN        NaN              NaN             NaN
# 4        NaN        NaN        NaN              NaN             NaN
# 5        NaN        NaN        NaN              NaN             NaN
# 6        NaN        NaN        NaN              NaN             NaN
# 7        NaN        NaN        NaN              NaN             NaN
# 8        NaN        NaN        NaN              NaN             NaN
# 9        NaN        NaN        NaN              NaN             NaN
#
#    rolling_mean_t30  rolling_mean_t90  rolling_mean_t180  rolling_std_t30  \
# 0               NaN               NaN                NaN              NaN
# 1               NaN               NaN                NaN              NaN
# 2               NaN               NaN                NaN              NaN
# 3               NaN               NaN                NaN              NaN
# 4               NaN               NaN                NaN              NaN
# 5               NaN               NaN                NaN              NaN
# 6               NaN               NaN                NaN              NaN
# 7               NaN               NaN                NaN              NaN
# 8               NaN               NaN                NaN              NaN
# 9               NaN               NaN                NaN              NaN
#
#    price_change_t1  price_change_t365  rolling_price_std_t7  \
# 0              NaN                NaN                   NaN
# 1              NaN                NaN                   NaN
# 2              NaN                NaN                   NaN
# 3              NaN                NaN                   NaN
# 4              NaN                NaN                   NaN
# 5              NaN                NaN                   NaN
# 6              NaN                NaN                   NaN
# 7              NaN                NaN                   NaN
# 8              NaN                NaN                   NaN
# 9              NaN                NaN                   NaN
#
#    rolling_price_std_t30  rolling_skew_t30  rolling_kurt_t30  year  month  \
# 0                    NaN               NaN               NaN  2013      7
# 1                    NaN               NaN               NaN  2013      7
# 2                    NaN               NaN               NaN  2013      7
# 3                    NaN               NaN               NaN  2013      7
# 4                    NaN               NaN               NaN  2013      7
# 5                    NaN               NaN               NaN  2013      7
# 6                    NaN               NaN               NaN  2013      7
# 7                    NaN               NaN               NaN  2013      7
# 8                    NaN               NaN               NaN  2013      7
# 9                    NaN               NaN               NaN  2013      7
#
#    week  day  dayofweek
# 0    29   18          3
# 1    29   18          3
# 2    29   18          3
# 3    29   18          3
# 4    29   18          3
# 5    29   18          3
# 6    29   18          3
# 7    29   18          3
# 8    29   18          3
# 9    29   18          3
